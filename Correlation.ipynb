# %% [markdown]
# <a href="https://colab.research.google.com/github/supercooler88/docker-python/blob/master/Correlation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

np.random.seed(4)

# 100 random integers between 0 and 50
x = np.random.randint(0, 50, 100)

# Positive Correlation with some noise
y = x + np.random.normal(0, 10, 100)

np.corrcoef(x, y)  # Return Pearson product-moment correlation coefficients
# Out:
# array([[1.        , 0.85021842],
#        [0.85021842, 1.        ]])

# %%
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
matplotlib.style.use('ggplot')

plt.scatter(x, y)
plt.show()

# %%
# 100 random integers between 0 and 50
x = np.random.randint(0, 50, 100)

# Negative Correlation with some noise
y = 100 - x + np.random.normal(0, 5, 100)

np.corrcoef(x, y)
# Out:
# array([[ 1.        , -0.94586333],
#        [-0.94586333,  1.        ]])

# %%
plt.scatter(x, y)
plt.show()

# %%
x = np.random.randint(0, 50, 100)
y = np.random.randint(0, 50, 100)

np.corrcoef(x, y)
# Out:
# array([[ 1.        , -0.02989408],
#        [-0.02989408,  1.        ]])

# %%
plt.scatter(x, y)
plt.show()

# %%
import pandas as pd

df = pd.DataFrame({'a': np.random.randint(0, 50, 100)})
df['b'] = df['a'] + np.random.normal(0, 10, 100) # positively correlated with 'a'
df['c'] = 100 - df['a'] + np.random.normal(0, 5, 100) # negatively correlated with 'a'
df['d'] = np.random.randint(0, 50, 100) # not correlated with 'a'

df.corr() # pearson correlation
# Out:
#           a         b         c         d
# a  1.000000  0.830199 -0.946582  0.100693
# b  0.830199  1.000000 -0.807378  0.121513
# c -0.946582 -0.807378  1.000000 -0.093014
# d  0.100693  0.121513 -0.093014  1.000000

# %%
pd.plotting.scatter_matrix(df, figsize=(10, 10))
plt.show()

# %%
age = np.array([7,6,8,5,6,9])
weight = np.array([12,8,12,10,11,13])
np.corrcoef(age, weight)
# Out:
# array([[1.        , 0.75955453],
#        [0.75955453, 1.        ]])
